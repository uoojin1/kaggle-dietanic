# %% [markdown]
# # Part 1. Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # set seaborn default for plots
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# fetch and see data
data = pd.read_csv('./input/train.csv')
test_data = pd.read_csv('./input/test.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# check null values in data
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Age, Cabin, Embarked have missing values and we need to fix them

# %%
# describe a feature
def describeFeature(data, feature):
    print(data[feature].describe())
    print("\nnull count:")
    print(data['Age'].isnull().value_counts())

# %%
# define pie plot
def plotTotal(data, feature):
    categories = data[feature].value_counts()
    print(categories)
    categories.plot.pie(subplots=True)

# %%
# plot descriptive feature vs target feature
def plotFeatureToTarget(data, feature, target):
    survived = data[data[target]==1][feature].value_counts()
    dead = data[data[target]==0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='pie', figsize=(12,15), subplots=True, autopct='%1.0f%%')
    df.plot(kind='bar', figsize=(12,5), stacked=False)

# %%
# define histogram plot
def plotHistogram(data, feature, kde=False):
    sns.distplot(a=data.dropna()[feature], kde=kde)

# %%
# ordinal feature vs target feature / with Factor feature as an option
def plotOrdinalFeatureToTarget(data, ordinal_feature, target, factor=None):
    sns.factorplot(ordinal_feature, target, hue=factor, data=data)

# %%
# plot categorical X continuous features To Categorical Target
def plotViolin(data, categorical_feature, continuous_feature, target):
    sns.violinplot(categorical_feature, continuous_feature, hue=target, data=data, split=True)

# %%
# plot continuous feature vs categorical target
def plotFacet(data, feature, target):
    facet = sns.FacetGrid(data, hue=target, aspect=3)
    facet.map(sns.kdeplot, feature, shade=True)
    facet.set(xlim=(0, data[feature].max()))
    facet.add_legend()
    plt.show()

# %%
# visualizing correlation between attributes
corr = data.corr()
sns.heatmap(corr) # only appies to non categorical variables

# %% [markdown]
# ### Types of Features
#
# #### 1. Categorical Feature: Nominal
#
# categorical feature: a feature that has 1 or more categories and the categories are not sortable in a meaningful way (i.e. male > female ??)
#
# #### 2. Categorical Feature: Ordinal
#
# ordinal feature: categorical feature that has relative ordering for sorting. ex) height category: Tall > Medium > Short
#
# #### 3. Continuous Feature
#
# continuous feature can take values between any 2 points. ex) Fare

# %%
# Analyzing the features,

# first 'Sex' attribute // a Categorical Feature

plotTotal(data, 'Sex')
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
plotFeatureToTarget(data, 'Sex', 'Survived')

# %% [markdown]
# ### 'Pclass' feature :: ordinal feature

# %%
plotTotal(data, 'Pclass')
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
plotFeatureToTarget(data, 'Pclass', 'Survived')

# %% [markdown]
# looks like most people are in the Pclass: 3 category.
# Survival rate is the highest in Pclass: 1 (63%)
# Survival rate is the lowest in Pclass: 3  (24%)

# %%
plotOrdinalFeatureToTarget(data, 'Pclass', 'Survived', 'Sex')

# %% [markdown]
# from the factorplot, we see that
#
# female in Pclass:1 has 95% survival rate
# generally, Pclass looks like a very important feature

# %% [markdown]
# ### 'Age' feature :: continuous feature

# %%
plotHistogram(data, 'Age', kde=True)

# %%
describeFeature(data, 'Age')
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
#
# null count:
# False    714
# True     177
# Name: Age, dtype: int64

# %%
plotViolin(data, 'Pclass', 'Age', 'Survived')

# %% [markdown]
# the age factor decreases as Pclass increases from 1-->3

# %%
plotFacet(data, 'Age', 'Survived')

# %% [markdown]
# observation:
# 0~14 yrs old had significantly higher survival rate than death rate
# 14~30 yrs old had higher death rate than survival rate
# 30+ yrs old had somewhat similar survival vs death rate

# %%
describeFeature(data, 'Age')
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
#
# null count:
# False    714
# True     177
# Name: Age, dtype: int64

# %% [markdown]
# 'Age' feature has some significant missing values. We need to fill this up by using some mechanism.
#
# We could use the Title (ex. Mr, Mrs, Miss, etc) to assign average age values to people with those titles.

# %%
# before making any changes, we should combine train and test data
train_test_data = [data, test_data]

# %%
for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract('([A-Za-z]+)\.')

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked Title
# 0      0  A/5 21171  7.25   NaN        S    Mr

# %%
test_data['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona'],
#       dtype=object)

# %%
data['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
pd.crosstab(data['Title'], data['Sex']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2" ><thead>    <tr>        <th class="index_name level0" >Title</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_c0b71d54_747f_11e9_a737_2cf0ee1e8bf2row0_col13" class="data row0 col13" >125</td>
#                         <td

# %% [markdown]
# looks like there are some misspelled Titles like Mlle and Mme that stand for Miss. we can replace these.
#
# also, we can replace Catp, Col --> Mr, because we know they are male

# %%
# doing some meaningful replacement
for dataset in train_test_data:
    dataset['Title'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Other'],inplace=True)

# %%
data['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
data.groupby('Title')['Age'].mean()
# Out:
# Title
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
# filling in the missing ages
for dataset in train_test_data:
    dataset['Age'].fillna(dataset.groupby('Title')['Age'].transform('median'), inplace=True)

# %%
plotFacet(data, 'Age', 'Survived')

# %%
plotHistogram(data[data['Survived']==1], 'Age')

# %%
plotHistogram(data[data['Survived']==0], 'Age')
